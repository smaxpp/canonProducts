# %%
import pandas as pd
df = pd.read_csv('lensList/lens.csv', index_col=0)

# %%
df
# Out:
#          aperture                                           lensName  \
# 0    Max Aperture                         Lenses (Updated 3/14/2016)
# 1             NaN                         Canon Extender EF 1.4x III
# 2             NaN                           Canon Extender EF 2x III
# 3           f/2.8  SIGMA 4.5mm f/2.8 EX DC HSM Circular Fisheye (...
# 4             f/4                        Canon EF 8-15mm USM Fisheye
# 5           F/3.5  Rokinon 8mm F3.5 HD\nFISHEYE (removable hood, ...
# 6           F/3.5                  Rokinon 8mm F/3.5 FISHEYE (APS-C)
# 7           f/3.5     SIGMA 8mm f/3.5 EX DG Circular Fisheye (prime)
# 8       f/4.5-5.6                      SIGMA 8-16mm f/4.5-5.6 DC HSM
# 9           F/2.8       Rokinon 10mm F/2.8\nULTRA WIDE ANGLE (APS-C)
# 10          f/2.8         SIGMA 10mm f/2.8 EX DC HSM Fisheye (prime)
# 11      f/3.5-4.5  Tamron 10-24mm f/3.5-4.5 Di II LD Aspherical [...
# 12      f/3.5-4.5              Tokina AT-X 10-17mm f/3.5-4.5 Fisheye
# ...

# %%
df2 = df[df['brand']=='']

# %%
df2
# Out:
# Empty DataFrame
# Columns: [aperture, lensName, max, min, price, brand, price2]
# Index: []

# %%
df['brand'].distinct_values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-571bedb10028> in <module>()
# ----> 1 df['brand'].distinct_values()
#
# /home/spark/miniconda3/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2667             if name in self._info_axis:
#    2668                 return self[name]
# -> 2669             return object.__getattribute__(self, name)
#    2670
#    2671     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'distinct_values'

# %%
df['brand'].values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-109b74a5c458> in <module>()
# ----> 1 df['brand'].values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
df['brand'].unique()
# Out:
# array(['Lenses', 'Canon', 'SIGMA', 'Rokinon', 'Tamron', 'Tokina', 'ZEISS',
#        'Irix', nan, 'YONGNUO'], dtype=object)

# %%
df[df['price2'] == 699.0]
# Out:
#      aperture                       lensName max  min price  brand  price2
# 8   f/4.5-5.6  SIGMA 8-16mm f/4.5-5.6 DC HSM  16  8 -  $699  SIGMA   699.0
# 42       f/4L          Canon EF 17-40mm USM   40   17  $699    NaN   699.0

# %%
df[42]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/spark/miniconda3/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1875             try:
# -> 1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4027)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3891)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12408)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12359)()
#
# KeyError: 42
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-4586623c0895> in <module>()
# ----> 1 df[42]
#
# ...
